# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_curve, auc, roc_curve
from sklearn.tree import DecisionTreeClassifier, export_graphviz
import graphviz
from sklearn.model_selection import cross_val_predict, cross_val_score

from google.colab import drive
drive.mount('/content/drive/')
df = pd.read_csv('/content/drive/MyDrive/BtlHocMay/Attribute DataSet.csv')

#Hiển thị thuộc tính các cột trong data
df.columns
#Hiển thị 5 hàng đầu tiên của data
df.head()

print("Dữ liệu gốc:", df.shape)

df['Style'].value_counts()

#Visualize mô hình đếm số lượng Style
count = df['Style'].value_counts()
sns.set_context(font_scale=1.5)
plt.figure(figsize=(10,5))
sns.barplot(count.index, count.values, alpha=0.6, palette="prism")
plt.ylabel('Count', fontsize=16)
plt.xlabel('Style', fontsize=16)
plt.title('Casual/Sexy/party/cute/vintage/bohemian/Briel/work/Novelty/sexy/Flare/OL/fashion/')
#plt.savefig("count_class.jpeg", format='jpeg', dpi=100)
plt.show()
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# Dữ liệu gốc: (500, 14)
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Visualize mô hình đếm số lượng Price
count = df['Price'].value_counts()
sns.set_context(font_scale=1.5)
plt.figure(figsize=(10,5))
sns.barplot(count.index, count.values, alpha=0.6, palette="prism")
plt.ylabel('Count', fontsize=16)
plt.xlabel('Price', fontsize=16)
plt.title('Average/Low/low/Medium/very-high/high/High')
#plt.savefig("count_class.jpeg", format='jpeg', dpi=100)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Visualize mô hình đếm số lượng Rating
count = df['Rating'].value_counts()
sns.set_context(font_scale=1.5)
plt.figure(figsize=(10,5))
sns.barplot(count.index, count.values, alpha=0.6, palette="prism")
plt.ylabel('Count', fontsize=16)
plt.xlabel('Rating', fontsize=16)
plt.title('')
#plt.savefig("count_class.jpeg", format='jpeg', dpi=100)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Visualize mô hình đếm số lượng Size
count = df['Size'].value_counts()
sns.set_context(font_scale=1.5)
plt.figure(figsize=(10,5))
sns.barplot(count.index, count.values, alpha=0.6, palette="prism")
plt.ylabel('Count', fontsize=16)
plt.xlabel('Size', fontsize=16)
plt.title('')
#plt.savefig("count_class.jpeg", format='jpeg', dpi=100)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Visualize mô hình đếm số lượng Season
count = df['Season'].value_counts()
sns.set_context(font_scale=1.5)
plt.figure(figsize=(10,5))
sns.barplot(count.index, count.values, alpha=0.6, palette="prism")
plt.ylabel('Count', fontsize=16)
plt.xlabel('Season', fontsize=16)
plt.title('')
#plt.savefig("count_class.jpeg", format='jpeg', dpi=100)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Visualize mô hình đếm số lượng NeckLine
count = df['NeckLine'].value_counts()
sns.set_context(font_scale=1.5)
plt.figure(figsize=(20,5))
sns.barplot(count.index, count.values, alpha=0.6, palette="prism")
plt.ylabel('Count', fontsize=16)
plt.xlabel('NeckLine', fontsize=16)
plt.title('')
#plt.savefig("count_class.jpeg", format='jpeg', dpi=100)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Visualize mô hình đếm số lượng SleeveLength
count = df['SleeveLength'].value_counts()
sns.set_context(font_scale=1.5)
plt.figure(figsize=(20,5))
sns.barplot(count.index, count.values, alpha=0.6, palette="prism")
plt.ylabel('Count', fontsize=16)
plt.xlabel('SleeveLength', fontsize=16)
plt.title('')
#plt.savefig("count_class.jpeg", format='jpeg', dpi=100)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Visualize mô hình đếm số lượng waiseline
count = df['waiseline'].value_counts()
sns.set_context(font_scale=1.5)
plt.figure(figsize=(9,5))
sns.barplot(count.index, count.values, alpha=0.6, palette="prism")
plt.ylabel('Count', fontsize=16)
plt.xlabel('waiseline', fontsize=16)
plt.title('')
#plt.savefig("count_class.jpeg", format='jpeg', dpi=100)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Visualize mô hình đếm số lượng Material
count = df['Material'].value_counts()
sns.set_context(font_scale=1.5)
plt.figure(figsize=(20,5))
sns.barplot(count.index, count.values, alpha=0.6, palette="prism")
plt.ylabel('Count', fontsize=16)
plt.xlabel('Material', fontsize=16)
plt.title('')
#plt.savefig("count_class.jpeg", format='jpeg', dpi=100)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Visualize mô hình đếm số lượng FabricType
count = df['FabricType'].value_counts()
sns.set_context(font_scale=1.5)
plt.figure(figsize=(20,5))
sns.barplot(count.index, count.values, alpha=0.6, palette="prism")
plt.ylabel('Count', fontsize=16)
plt.xlabel('FabricType', fontsize=16)
plt.title('')
#plt.savefig("count_class.jpeg", format='jpeg', dpi=100)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Visualize mô hình đếm số lượng Decoration
count = df['Decoration'].value_counts()
sns.set_context(font_scale=1.5)
plt.figure(figsize=(20,5))
sns.barplot(count.index, count.values, alpha=0.6, palette="prism")
plt.ylabel('Count', fontsize=16)
plt.xlabel('Decoration', fontsize=16)
plt.title('')
#plt.savefig("count_class.jpeg", format='jpeg', dpi=100)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Visualize mô hình đếm số lượng Pattern Type
count = df['Pattern Type'].value_counts()
sns.set_context(font_scale=1.5)
plt.figure(figsize=(20,5))
sns.barplot(count.index, count.values, alpha=0.6, palette="prism")
plt.ylabel('Count', fontsize=16)
plt.xlabel('Pattern Type', fontsize=16)
plt.title('')
#plt.savefig("count_class.jpeg", format='jpeg', dpi=100)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Visualize mô hình đếm số lượng Recommendation
count = df['Recommendation'].value_counts()
sns.set_context(font_scale=1.5)
plt.figure(figsize=(7,5))
sns.barplot(count.index, count.values, alpha=0.6, palette="prism")
plt.ylabel('Count', fontsize=16)
plt.xlabel('Recommendation', fontsize=16)
plt.title('')
#plt.savefig("count_class.jpeg", format='jpeg', dpi=100)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
